# %%
# %matplotlib inline

# %run -i 'CNN_LSTM.py'
# Out:
#  num_epochs:  30
# Train Data Shape:  (53376, 1, 3000)   Test Data Shape:  (3712, 1, 3000)
#
#
# There are 3484709 (3.48 million) parameters in this neural network
# Epoch [1/30] , Accuracy :  30.40130395683453
# Test Accuracy: 40.355603448275865 %
#
# Epoch [2/30] , Accuracy :  37.28080035971223
# Test Accuracy: 36.74568965517241 %
#
# Epoch [3/30] , Accuracy :  44.982763788968825
# Test Accuracy: 34.779094827586206 %
#
# Epoch [4/30] , Accuracy :  51.999025779376495
# Test Accuracy: 35.9375 %
#
# Epoch [5/30] , Accuracy :  58.09165167865707
# Test Accuracy: 40.247844827586206 %
#
# Epoch [6/30] , Accuracy :  62.25082434052758
# Test Accuracy: 41.029094827586206 %
#
# Epoch [7/30] , Accuracy :  65.52008393285371
# Test Accuracy: 42.672413793103445 %
#
# Epoch [8/30] , Accuracy :  68.2216726618705
# Test Accuracy: 40.894396551724135 %
#
# Epoch [9/30] , Accuracy :  70.37619904076739
# Test Accuracy: 47.009698275862064 %
#
# Epoch [10/30] , Accuracy :  74.1306954436451
# ...
