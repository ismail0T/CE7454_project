# %%
# %matplotlib inline

# %run -i 'CNN_LSTM.py'
# Out:
#  num_epochs:  30
# Train Data Shape:  (53376, 1, 3000)   Test Data Shape:  (3712, 1, 3000)
#
#
# There are 647045 (0.65 million) parameters in this neural network
# Epoch [1/30] , Accuracy :  30.260791366906474
# Test Accuracy: 40.355603448275865 %
#
# Epoch [2/30] , Accuracy :  30.826588729016784
# Test Accuracy: 41.62176724137931 %
#
# Epoch [3/30] , Accuracy :  39.46342925659472
# Test Accuracy: 40.16702586206897 %
#
# Epoch [4/30] , Accuracy :  42.47601918465228
# Test Accuracy: 53.609913793103445 %
#
# Epoch [5/30] , Accuracy :  53.26176558752997
# Test Accuracy: 56.60021551724138 %
#
# Epoch [6/30] , Accuracy :  61.82179256594724
# Test Accuracy: 63.766163793103445 %
#
# Epoch [7/30] , Accuracy :  66.29758693045564
# Test Accuracy: 67.24137931034483 %
#
# Epoch [8/30] , Accuracy :  68.5064448441247
# Test Accuracy: 67.42995689655173 %
#
# Epoch [9/30] , Accuracy :  70.87080335731414
# Test Accuracy: 71.03987068965517 %
#
# Epoch [10/30] , Accuracy :  73.42063848920863
# ...
