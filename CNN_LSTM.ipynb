# %%
# %matplotlib inline

# %run -i 'CNN_LSTM.py'
# Out:
# num_folds:  20  num_epochs:  50
# Train Data Shape:  (56256, 1, 3000)   Test Data Shape:  (2112, 1, 3000)
#
#
#
# Fold <1>
# There are 647045 (0.65 million) parameters in this neural network
# Epoch [1/50] , Accuracy :  29.765713879408416
# Test Accuracy: 43.60795454545455 %
#
# Epoch [2/50] , Accuracy :  29.945250284414104
# Test Accuracy: 43.60795454545455 %
#
# Epoch [3/50] , Accuracy :  29.945250284414104
# Test Accuracy: 43.60795454545455 %
#
# Epoch [4/50] , Accuracy :  33.54486632536974
# Test Accuracy: 50.71022727272727 %
#
# Epoch [5/50] , Accuracy :  43.186504550625706
# Test Accuracy: 56.34469696969697 %
#
# Epoch [6/50] , Accuracy :  50.27019340159272
# Test Accuracy: 60.03787878787878 %
#
# Epoch [7/50] , Accuracy :  59.012372013651884
# Test Accuracy: 65.3409090909091 %
#
# Epoch [8/50] , Accuracy :  65.4063566552901
# Test Accuracy: 58.23863636363637 %
#
# Epoch [9/50] , Accuracy :  67.43813993174061
# Test Accuracy: 71.35416666666666 %
#
# ...
