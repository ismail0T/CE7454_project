# %%
# %matplotlib inline

# %run -i 'CNN_LSTM.py'
# Out:
# num_folds:  20  num_epochs:  50
# Train Data Shape:  (56256, 1, 3000)   Test Data Shape:  (2112, 1, 3000)
#
#
#
# Fold <1>
# There are 1043589 (1.04 million) parameters in this neural network
# Epoch [1/50] , Accuracy :  29.906143344709896
# Test Accuracy: 43.60795454545455 %
#
# Epoch [2/50] , Accuracy :  29.94169510807736
# Test Accuracy: 43.60795454545455 %
#
# Epoch [3/50] , Accuracy :  29.94169510807736
# Test Accuracy: 43.60795454545455 %
#
# Epoch [4/50] , Accuracy :  33.53064562002275
# Test Accuracy: 43.08712121212121 %
#
# Epoch [5/50] , Accuracy :  40.687215585893064
# Test Accuracy: 46.07007575757576 %
#
# Epoch [6/50] , Accuracy :  48.79301763367463
# Test Accuracy: 57.859848484848484 %
#
# Epoch [7/50] , Accuracy :  52.865472127417526
# Test Accuracy: 62.5 %
#
# Epoch [8/50] , Accuracy :  57.691624004550626
# Test Accuracy: 57.71780303030303 %
#
# Epoch [9/50] , Accuracy :  64.44290386803185
# Test Accuracy: 69.41287878787878 %
#
# ...
